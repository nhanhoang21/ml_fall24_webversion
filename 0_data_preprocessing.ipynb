# %%
import pandas as pd
import numpy as np

# %%
# Set the option to avoid silent downcasting warnings in the future
pd.set_option('future.no_silent_downcasting', True)

# %%
# Load the dataset
data = pd.read_excel('CS5805_Group1_Database.xlsx', header=None)

# %%
# Extract the first three rows as headers
header = data.iloc[:3]

# Step 1: Replace "\n" with a space in header cells
header = header.replace({r'\n': ' '}, regex=True)

# Step 2: Fill vertically first to extend merged row headers
header_filled_row = header.ffill(axis=0)

# Step 3: Then fill horizontally to extend merged column headers
header_filled = header_filled_row.ffill(axis=1).fillna('-')

header_filled
# Out:
#             0            1            2         3         4         5     6   \
# 0  Article  ID  Specimen ID  Specimen ID  #Members  #Members  #Members  Type
# 1  Article  ID  Specimen ID  Specimen ID  #Members  #Members  #Members  Type
# 2  Article  ID  by Kantekin   by Authors         C     Blong    Btrans  Type
#
#      7                        8                        9   ...          64  \
# 0  Type  FRCC Application Region  FRCC Application Region  ...  Axial Load
# 1  Type  FRCC Application Region  FRCC Application Region  ...  Axial Load
# 2  Type                    Joint                     BPHR  ...           n
#
#               65             66             67             68             69  \
# 0  Joint stirrup  Joint stirrup  Joint stirrup  Joint stirrup  Joint stirrup
# 1  Joint stirrup  Joint stirrup  Joint stirrup  Joint stirrup  Joint stirrup
# 2         d (mm)       A0 (mm2)         s (mm)       fy (MPa)         ρgross
#
#                                   70                                 71  \
# 0  Coefficients for Kantekin & Bakir  Coefficients for Kantekin & Bakir
# 1  Coefficients for Kantekin & Bakir  Coefficients for Kantekin & Bakir
# 2                                  α                                  ϐ
#
#                                   72             73
# 0  Coefficients for Kantekin & Bakir  vj,exp  (MPa)
# 1  Coefficients for Kantekin & Bakir  vj,exp  (MPa)
# 2                                  γ  vj,exp  (MPa)
#
# [3 rows x 74 columns]

# %%
# Initialize an empty list to store the combined headers
combined_headers = []

# Loop through each column to get unique values and join them with '_'
for col in header_filled.columns:
    # Obtain unique values in each column
    col_values = header_filled[col].unique()
    # Join the unique values with an underscore separator
    combined_header = "_".join(col_values)
    # Append the resulting combined header to the list
    combined_headers.append(combined_header)

# Set the new headers to the data
data.columns = combined_headers

# Drop the header rows from the data and reset index for a clean DataFrame
data = data.iloc[3:].reset_index(drop=True)

data.head()
# Out:
#   Article  ID Specimen ID_by Kantekin Specimen ID_by Authors #Members_C  \
# 0          11                    11_2                HC-JO-U          2
# 1          11                    11_3                HC-JX-U          2
# 2          12                    12_2                   EJ-2          2
# 3          12                    12_3                   EJ-3          2
# 4          12                    12_4                   EJ-4          2
#
#   #Members_Blong #Members_Btrans Type      Type FRCC Application Region_Joint  \
# 0              1               1   E1  Exterior                             1
# 1              1               1   E1  Exterior                             1
# 2              1               0   E0  Exterior                             1
# 3              1               0   E0  Exterior                             1
# 4              1               0   E0  Exterior                             1
#
#   FRCC Application Region_BPHR  ... Axial Load_n Joint stirrup_d (mm)  \
# 0                            1  ...          0.2                   10
# 1                            1  ...          0.2                    0
# 2                            1  ...          0.5                    6
# 3                            1  ...          0.5                    6
# 4                            1  ...          0.3                    0
#
#   Joint stirrup_A0 (mm2) Joint stirrup_s (mm) Joint stirrup_fy (MPa)  \
# 0              78.539816                  150                    472
# 1                      0                    -                      0
# 2              28.274334                   96                 353.56
# 3              28.274334                  105                 353.56
# 4                      0                    -                      0
#
#   Joint stirrup_ρgross Coefficients for Kantekin & Bakir_α  \
# 0             0.001269                                0.25
# 1                    0                                0.25
# 2             0.000927                                0.25
# 3             0.000927                                0.25
# 4                    0                                0.25
#
#   Coefficients for Kantekin & Bakir_ϐ Coefficients for Kantekin & Bakir_γ  \
# 0                                0.75                                 1.5
# 1                                0.75                                 1.5
# 2                                0.75                                 1.5
# 3                                0.75                                 1.5
# 4                                0.75                                 1.5
#
#   vj,exp  (MPa)
# 0      5.397781
# 1      4.619068
# 2          6.78
# 3         7.565
# 4        5.8225
#
# [5 rows x 74 columns]

# %%
# Print each column header along with its index number to allow easier identification of columns to keep
for idx, col_name in enumerate(data.columns):
    print(f"Index {idx}: {col_name}")
# Out:
# Index 0: Article  ID
# Index 1: Specimen ID_by Kantekin
# Index 2: Specimen ID_by Authors
# Index 3: #Members_C
# Index 4: #Members_Blong
# Index 5: #Members_Btrans
# Index 6: Type
# Index 7: Type
# Index 8: FRCC Application Region_Joint
# Index 9: FRCC Application Region_BPHR
# Index 10: FRCC Application Region_CPHR
# Index 11: FRCC Application Region_Slab
# Index 12: Relative FRCC Application_BPHR/hb
# Index 13: Relative FRCC Application_BPHR/hc,top
# Index 14: Relative FRCC Application_BPHR/hc,bot
# Index 15: Fiber_No of fibers
# Index 16: Fiber_Fiber 1_Type
# Index 17: Fiber_Fiber 1_ρ (kg/m3)
# Index 18: Fiber_Fiber 1_L  (mm)
# Index 19: Fiber_Fiber 1_D (mm)
# Index 20: Fiber_Fiber 1_(L/D)f
# Index 21: Fiber_Fiber 1_Vf
# Index 22: Fiber_Fiber 1_σt (MPa)
# Index 23: Fiber_Fiber 1_E  (MPa)
# Index 24: Fiber_Fiber 1_RI1
# Index 25: Fiber_Fiber 2_Type
# Index 26: Fiber_Fiber 2_ρ (kg/m3)
# Index 27: Fiber_Fiber 2_L (mm)
# Index 28: Fiber_Fiber 2_D (mm)
# Index 29: Fiber_Fiber 2_(L/D)f
# Index 30: Fiber_Fiber 2_Vf
# Index 31: Fiber_Fiber 2_σt (MPa)
# Index 32: Fiber_Fiber 2_E  (MPa)
# Index 33: Fiber_Fiber 2_RI2
# Index 34: Fiber_Fiber 3_Type
# Index 35: Fiber_Fiber 3_ρ (kg/m3)
# Index 36: Fiber_Fiber 3_L (mm)
# Index 37: Fiber_Fiber 3_D (mm)
# Index 38: Fiber_Fiber 3_(L/D)f
# Index 39: Fiber_Fiber 3_Vf
# Index 40: Fiber_Fiber 3_σt (MPa)
# Index 41: Fiber_Fiber 3_E  (MPa)
# Index 42: Fiber_Fiber 3_RI3
# Index 43: Holistic parameters for fibers_(Vf)tot
# Index 44: Holistic parameters for fibers_(L/D)mod
# Index 45: Holistic parameters for fibers_RImod
# Index 46: Composite properties_σmu (Mpa)
# Index 47: Composite properties_τ (Mpa)
# Index 48: Composite properties_ τ/σmu
# Index 49: Composite properties_EACI544
# Index 50: Composite properties_fc' (MPa)
# Index 51: Composite properties_σcc (MPa)
# Index 52: Beam Dm.(mm)_hb
# Index 53: Beam Dm.(mm)_bb
# Index 54: Beam Dm.(mm)_bb / hb
# Index 55: Beam Dm.(mm)_as'
# Index 56: Beam Dm.(mm)_h0 - as'
# Index 57: Clmn Dm.(mm)_hc
# Index 58: Clmn Dm.(mm)_hj
# Index 59: Clmn Dm.(mm)_bc
# Index 60: Clmn Dm.(mm)_bc / hc
# Index 61: Joint_hc / bb
# Index 62: Joint Dm mm & mm2_bj
# Index 63: Joint Dm mm & mm2_Aj
# Index 64: Axial Load_n
# Index 65: Joint stirrup_d (mm)
# Index 66: Joint stirrup_A0 (mm2)
# Index 67: Joint stirrup_s (mm)
# Index 68: Joint stirrup_fy (MPa)
# Index 69: Joint stirrup_ρgross
# Index 70: Coefficients for Kantekin & Bakir_α
# Index 71: Coefficients for Kantekin & Bakir_ϐ
# Index 72: Coefficients for Kantekin & Bakir_γ
# Index 73: vj,exp  (MPa)

# %%
# Specify the indices of columns you want to keep
columns_to_keep = [7, 43, 44, 45, 50, 51, 54, 56, 58, 60, 61, 62, 64, 66, 67, 68, 69, 70, 71, 72]

# Create a new DataFrame (features X) with only the selected columns
X = data.iloc[:, columns_to_keep]

X.head()
# Out:
#        Type Holistic parameters for fibers_(Vf)tot  \
# 0  Exterior                                 0.0212
# 1  Exterior                                 0.0212
# 2  Exterior                                  0.013
# 3  Exterior                                  0.013
# 4  Exterior                                  0.013
#
#   Holistic parameters for fibers_(L/D)mod  \
# 0                              307.692308
# 1                              307.692308
# 2                                      65
# 3                                      65
# 4                                      65
#
#   Holistic parameters for fibers_RImod Composite properties_fc' (MPa)  \
# 0                             6.523077                          33.93
# 1                             6.523077                          33.93
# 2                                0.845                        96.6735
# 3                                0.845                        91.5585
# 4                                0.845                        83.5605
#
#   Composite properties_σcc (MPa) Beam Dm.(mm)_bb / hb  Beam Dm.(mm)_h0 - as'  \
# 0                       3.611467                   0.5                   361
# 1                       3.611467                   0.5                   361
# 2                       6.096006                   0.6                   192
# 3                       5.932545                   0.6                   210
# 4                       5.667509                   0.6                   198
#
#   Clmn Dm.(mm)_hj Clmn Dm.(mm)_bc / hc Joint_hc / bb  Joint Dm mm & mm2_bj  \
# 0             330                    1           1.32                  330
# 1             330                    1           1.32                  330
# 2             200                    1       1.333333                  200
# 3             200                    1       1.333333                  200
# 4             200                    1       1.333333                  200
#
#   Axial Load_n Joint stirrup_A0 (mm2) Joint stirrup_s (mm)  \
# 0          0.2              78.539816                  150
# 1          0.2                      0                    -
# 2          0.5              28.274334                   96
# 3          0.5              28.274334                  105
# 4          0.3                      0                    -
#
#   Joint stirrup_fy (MPa) Joint stirrup_ρgross  \
# 0                    472             0.001269
# 1                      0                    0
# 2                 353.56             0.000927
# 3                 353.56             0.000927
# 4                      0                    0
#
#   Coefficients for Kantekin & Bakir_α Coefficients for Kantekin & Bakir_ϐ  \
# 0                                0.25                                0.75
# 1                                0.25                                0.75
# 2                                0.25                                0.75
# 3                                0.25                                0.75
# 4                                0.25                                0.75
#
#   Coefficients for Kantekin & Bakir_γ
# 0                                 1.5
# 1                                 1.5
# 2                                 1.5
# 3                                 1.5
# 4                                 1.5

# %%
# Convert 'Exterior' to 0 and 'Interior' to 1 in 'Type' column, and convert '-' to 0 in 'Joint stirrup_s (mm)' column
X.loc[:, 'Type'] = X['Type'].map({'Exterior': 0, 'Interior': 1})
X.loc[:, 'Joint stirrup_s (mm)'] = X['Joint stirrup_s (mm)'].replace('-', 0)

X.head()
# Out:
#   Type Holistic parameters for fibers_(Vf)tot  \
# 0    0                                 0.0212
# 1    0                                 0.0212
# 2    0                                  0.013
# 3    0                                  0.013
# 4    0                                  0.013
#
#   Holistic parameters for fibers_(L/D)mod  \
# 0                              307.692308
# 1                              307.692308
# 2                                      65
# 3                                      65
# 4                                      65
#
#   Holistic parameters for fibers_RImod Composite properties_fc' (MPa)  \
# 0                             6.523077                          33.93
# 1                             6.523077                          33.93
# 2                                0.845                        96.6735
# 3                                0.845                        91.5585
# 4                                0.845                        83.5605
#
#   Composite properties_σcc (MPa) Beam Dm.(mm)_bb / hb  Beam Dm.(mm)_h0 - as'  \
# 0                       3.611467                   0.5                   361
# 1                       3.611467                   0.5                   361
# 2                       6.096006                   0.6                   192
# 3                       5.932545                   0.6                   210
# 4                       5.667509                   0.6                   198
#
#   Clmn Dm.(mm)_hj Clmn Dm.(mm)_bc / hc Joint_hc / bb  Joint Dm mm & mm2_bj  \
# 0             330                    1           1.32                  330
# 1             330                    1           1.32                  330
# 2             200                    1       1.333333                  200
# 3             200                    1       1.333333                  200
# 4             200                    1       1.333333                  200
#
#   Axial Load_n Joint stirrup_A0 (mm2) Joint stirrup_s (mm)  \
# 0          0.2              78.539816                  150
# 1          0.2                      0                    0
# 2          0.5              28.274334                   96
# 3          0.5              28.274334                  105
# 4          0.3                      0                    0
#
#   Joint stirrup_fy (MPa) Joint stirrup_ρgross  \
# 0                    472             0.001269
# 1                      0                    0
# 2                 353.56             0.000927
# 3                 353.56             0.000927
# 4                      0                    0
#
#   Coefficients for Kantekin & Bakir_α Coefficients for Kantekin & Bakir_ϐ  \
# 0                                0.25                                0.75
# 1                                0.25                                0.75
# 2                                0.25                                0.75
# 3                                0.25                                0.75
# 4                                0.25                                0.75
#
#   Coefficients for Kantekin & Bakir_γ
# 0                                 1.5
# 1                                 1.5
# 2                                 1.5
# 3                                 1.5
# 4                                 1.5

# %%
# Create a joint shear strength vector (y)
y = data.iloc[:, -1]

y.head()
# Out:
# 0    5.397781
# 1    4.619068
# 2        6.78
# 3       7.565
# 4      5.8225
# Name: vj,exp  (MPa), dtype: object

# %%
# Save X and y to CSV files
X.to_csv('X_data.csv',  header=False, index=False)  # Save X data
y.to_csv('y_data.csv', header=False, index=False)  # Save y data
